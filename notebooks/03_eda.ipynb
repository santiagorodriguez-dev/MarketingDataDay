# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_excel("../data/KEYWORDS.xlsx", index_col=0)

# %%
df.head()
# Out:
#                   Currency  Avg. monthly searches  \
# Keyword
# bolso tote             EUR                   8100
# bolsas totes           EUR                   8100
# bolso tote bag         EUR                   4400
# bolso tote mujer       EUR                   2400
# bolsos tote mujer      EUR                   2400
#
#                    Cambio en los últimos tres meses  Cambio interanual  \
# Keyword
# bolso tote                                    -0.19              -0.19
# bolsas totes                                  -0.19              -0.19
# bolso tote bag                                 0.00               0.00
# bolso tote mujer                              -0.19               0.53
# bolsos tote mujer                             -0.19               0.53
#
#                   Competition  Competition (indexed value)  \
# Keyword
# bolso tote               Alto                          100
# bolsas totes             Alto                          100
# bolso tote bag           Alto                          100
# bolso tote mujer         Alto                          100
# bolsos tote mujer        Alto                          100
#
#                    Top of page bid (low range) Top of page bid (high range)  \
# Keyword
# bolso tote                                0.08                         0.49
# bolsas totes                              0.08                         0.49
# bolso tote bag                            0.15                         0.65
# bolso tote mujer                          0.07                         0.40
# bolsos tote mujer                         0.07                         0.40
#
#                    Ad impression share  Organic impression share  \
# Keyword
# bolso tote                         NaN                       NaN
# bolsas totes                       NaN                       NaN
# bolso tote bag                     NaN                       NaN
# bolso tote mujer                   NaN                       NaN
# bolsos tote mujer                  NaN                       NaN
#
#                    Organic average position  In account?  In plan?  \
# Keyword
# bolso tote                              NaN          NaN       NaN
# bolsas totes                            NaN          NaN       NaN
# bolso tote bag                          NaN          NaN       NaN
# bolso tote mujer                        NaN          NaN       NaN
# bolsos tote mujer                       NaN          NaN       NaN
#
#                    Searches: Nov 2022  Searches: Dec 2022  Searches: Jan 2023  \
# Keyword
# bolso tote                       9900                9900                9900
# bolsas totes                     9900                9900                9900
# bolso tote bag                   2400                2900                2400
# bolso tote mujer                 1300                1300                1600
# bolsos tote mujer                1300                1300                1600
#
#                    Searches: Feb 2023  Searches: Mar 2023  Searches: Apr 2023  \
# Keyword
# bolso tote                       8100                6600                5400
# bolsas totes                     8100                6600                5400
# bolso tote bag                   1900                2400                1900
# bolso tote mujer                 1300                1600                1300
# bolsos tote mujer                1300                1600                1300
#
#                    Searches: May 2023  Searches: Jun 2023  Searches: Jul 2023  \
# Keyword
# bolso tote                       6600               14800                6600
# bolsas totes                     6600               14800                6600
# bolso tote bag                   2400                6600                2900
# bolso tote mujer                 1600                1300                1300
# bolsos tote mujer                1600                1300                1300
#
#                    Searches: Aug 2023  Searches: Sep 2023  Searches: Oct 2023  \
# Keyword
# bolso tote                       9900               12100                8100
# bolsas totes                     9900               12100                8100
# bolso tote bag                   4400                6600                4400
# bolso tote mujer                 2400                2400                1900
# bolsos tote mujer                2400                2400                1900
#
#                    Searches: Nov 2023  Searches: Dec 2023  Searches: Jan 2024  \
# Keyword
# bolso tote                       9900                9900                9900
# bolsas totes                     9900                9900                9900
# bolso tote bag                   5400                5400                6600
# bolso tote mujer                 1900                2400                3600
# bolsos tote mujer                1900                2400                3600
#
#                    Searches: Feb 2024  Searches: Mar 2024  Searches: Apr 2024  \
# Keyword
# bolso tote                       6600                6600                6600
# bolsas totes                     6600                6600                6600
# bolso tote bag                   5400                4400                4400
# bolso tote mujer                 2400                2400                2400
# bolsos tote mujer                2400                2400                2400
#
#                    Searches: May 2024  Searches: Jun 2024  Searches: Jul 2024  \
# Keyword
# bolso tote                       5400                5400                6600
# bolsas totes                     5400                5400                6600
# bolso tote bag                   4400                4400                4400
# bolso tote mujer                 2400                2400                2900
# bolsos tote mujer                2400                2400                2900
#
#                    Searches: Aug 2024  Searches: Sep 2024  Searches: Oct 2024
# Keyword
# bolso tote                       8100                8100                6600
# bolsas totes                     8100                8100                6600
# bolso tote bag                   4400                4400                4400
# bolso tote mujer                 3600                3600                2900
# bolsos tote mujer                3600                3600                2900

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file("../data/KEYWORDS_ANALISIS.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
